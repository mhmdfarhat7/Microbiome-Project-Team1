# %%
import pandas as pd

# שם הקובץ (נמצא באותה תיקיה של הסקריפט)
file_path = "sandpiper1.0.0.condensed.summary.phylum.csv.gz"

# טען את הקובץ
df = pd.read_csv(file_path, compression="gzip")

# קח את השורה הראשונה והחמש עמודות הראשונות
first_row_first_5_cols = df.iloc[0, :5]

print(first_row_first_5_cols)
# Out:
# biorun                             DRR070900
# unassigned                              1.13
# d__Archaea;p__Thermoproteota             0.0
# d__Archaea;p__Halobacteriota             0.0
# d__Archaea;p__Methanobacteriota          0.0
# Name: 0, dtype: object
